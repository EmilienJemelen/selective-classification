# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import torch
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import torch.nn as nn
import numpy as np
import pickle
import pandas as pd
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import math
import scipy.special
import random as rd
import matplotlib.pyplot as plt
import torch.nn.functional as F
import torchvision.models as models
from torchvision.models import VGG16_Weights
from tqdm import tqdm
import torch.optim.lr_scheduler as lr_scheduler
from python_scripts.sgr_utils import *
from python_scripts.plotting import *
from scipy.special import gammaln
import warnings
warnings.filterwarnings("ignore")

print("GPU Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# GPU Available: True
# GPU Name: NVIDIA GeForce RTX 4060

# %%
sgr_df = pickle.load(open('sgr_set_cnn','rb')) 
sgr_df = sgr_df.sample(frac=1, random_state=42)
print(sgr_df.shape)
sgr_df.head() # balanced CIFAR-2 dataset
# Out:
# (7000, 3)
#       y_true  y_pred        SR
# 6500     0.0     0.0  0.929581
# 2944     0.0     0.0  0.982615
# 2024     1.0     1.0  0.542768
# 263      0.0     0.0  0.822609
# 4350     0.0     0.0  0.953512

# %%
delta = 0.001
greedy_search_steps_num = 50 # increase number of search steps for more precise metrics bounds
metric_targets=[i/1000 for i in integers_exp_spacing(5,300)]
proportions_1 = np.linspace(0.01,0.5,15) # for classes imbalance impact study

# %%
train_set = sgr_df.iloc[:2*int(len(sgr_df)/3)]
train_set = train_set.sort_values('SR', ascending=True).reset_index(drop=True).copy()
test_set = sgr_df.iloc[2*int(len(sgr_df)/3):]

# %% [markdown]
# ## <font color = 'yellow'> 1. __0/1 standard risk control__
# Dichotomy search for upper bound

# %% [markdown]
# #### <font color = 'violet'> 1.1. Risk coverage trade-offs

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, mode='dicho')#, steps=greedy_search_steps_num)
display(results)
metric_plots(results, ylabel='0/1 risk', xlim1=[0,1], xlim2=[0.4,1], ylim=[0,max(results.metric_bound)])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
#       2                          delta=delta, metric_targets=metric_targets, mode='dicho')#, steps=greedy_search_steps_num)
#       3 display(results)
#       4 metric_plots(results, ylabel='0/1 risk', xlim1=[0,1], xlim2=[0.4,1], ylim=[0,max(results.metric_bound)])
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\sgr_utils.py:215, in SGR_at_targets(train_set, test_set, k, delta, metric_targets, metric, union, mode, steps)
#     212 for r_star in metric_targets:
#     214     if mode == 'dicho':
# --> 215         sgr_dico = SGR_dicho(delta, r_star, train_set, k, metric = metric, union = union)
#     216     elif mode == 'greedy':
#     217         sgr_dico = SGR_greedy_search(delta, r_star, train_set, metric, xi=1e-3, steps=steps)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\sgr_utils.py:131, in SGR_dicho(delta, r_star, Sm, k, metric, xi, union)
#     128 selected_samples = Sm.loc[Sm.SR >= theta]
#     129 selected_errs_count = emp_errs_count(selected_samples, loss = metric)
# --> 131 b = B_star(desired_prob,
#     132            selected_errs_count,
#     133            selected_samples.shape[0])
#     135 if (selected_samples.shape[0]==0) or ((selected_errs_count==0) and (b >= r_star)): #terminal condition
#     136     return {}
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
#     [... skipping similar frames: B_star at line 77 (3 times)]
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
#     [... skipping similar frames: B_star at line 79 (1 times)]
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
#     [... skipping similar frames: B_star at line 77 (1 times)]
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:74, in B_star(delta, e, n, eps, b1, b2)
#      71     return 1-delta**(1/n)
#      73 b = (b1+b2)/2 # middle of segment
# ---> 74 if abs(binom_sum(b,e,n) - delta) < eps:
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:55, in binom_sum(b, e, n)
#      49 if e < n:
#      50     v = np.array([
#      51         np.exp(
#      52             binomial_log(n, j)
#      53             +j*np.log(b)
#      54             +(n-j)*np.log(1-b)) for j in range(e+1)])
# ---> 55     return np.sum(v)
#      56 elif e == n:
#      57     return 1
#
# File c:\Users\ejeme\Documents\python_repos\SGR\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:2485, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2482         return out
#    2483     return res
# -> 2485 return _wrapreduction(
#    2486     a, np.add, 'sum', axis, dtype, out,
#    2487     keepdims=keepdims, initial=initial, where=where
#    2488 )
#
# File c:\Users\ejeme\Documents\python_repos\SGR\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# __Comment__ :
#
# At 100% coverage one can observe 1- the classifier accuracy

# %% [markdown]
# #### <font color = 'violet'> 1.2. Evolution of trade-offs as class imbalance increases

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, 
                                                   sgr_df, delta, mode='dicho', 
                                                   metric='standard')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='0/1 risk', xlim1= [0, 1], xlim2= [0.4, 1],
                            ylim=[0,max(all_propor_dfs.metric_bound)])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets,
#       2                                                    sgr_df, delta, mode='dicho',
#       3                                                    metric='standard')
#       4 metric_plots_with_imbalance(all_propor_dfs, proportions_1,
#       5                             ylabel='0/1 risk', xlim1= [0, 1], xlim2= [0.4, 1],
#       6                             ylim=[0,max(all_propor_dfs.metric_bound)])
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\sgr_utils.py:268, in SGR_at_targets_on_imbalanced_sets(proportions_of_1, metric_targets, sgr_df, delta, mode, greedy_search_steps_num, metric)
#     265 train_set_ = train_set_.sort_values('SR', ascending=True).reset_index(drop=True).copy()
#     266 test_set_ = imbalanced_set.iloc[2*int(imbalanced_set.shape[0]/3):]
# --> 268 results = SGR_at_targets(train_set_, test_set_, k=int(np.log2(train_set_.shape[0])),
#     269                         delta=delta, metric_targets=metric_targets, metric=metric,
#     270                         mode=mode, steps=greedy_search_steps_num)
#     271 results['proportion_1'] = proportion_1
#     272 all_propor_dfs = pd.concat([all_propor_dfs, results]).reset_index(drop=True)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\sgr_utils.py:215, in SGR_at_targets(train_set, test_set, k, delta, metric_targets, metric, union, mode, steps)
#     212 for r_star in metric_targets:
#     214     if mode == 'dicho':
# --> 215         sgr_dico = SGR_dicho(delta, r_star, train_set, k, metric = metric, union = union)
#     216     elif mode == 'greedy':
#     217         sgr_dico = SGR_greedy_search(delta, r_star, train_set, metric, xi=1e-3, steps=steps)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\sgr_utils.py:131, in SGR_dicho(delta, r_star, Sm, k, metric, xi, union)
#     128 selected_samples = Sm.loc[Sm.SR >= theta]
#     129 selected_errs_count = emp_errs_count(selected_samples, loss = metric)
# --> 131 b = B_star(desired_prob,
#     132            selected_errs_count,
#     133            selected_samples.shape[0])
#     135 if (selected_samples.shape[0]==0) or ((selected_errs_count==0) and (b >= r_star)): #terminal condition
#     136     return {}
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
#     [... skipping similar frames: B_star at line 77 (1 times)]
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
#     [... skipping similar frames: B_star at line 79 (5 times), B_star at line 77 (5 times)]
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:74, in B_star(delta, e, n, eps, b1, b2)
#      71     return 1-delta**(1/n)
#      73 b = (b1+b2)/2 # middle of segment
# ---> 74 if abs(binom_sum(b,e,n) - delta) < eps:
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:52, in binom_sum(b, e, n)
#      43 """
#      44 binomial sum of term b in [0,1]
#      45 with binomial coefs "j among n"
#      46 for j in 0,1,...,e
#      47 it is the proba of doing at most e errors among n Bernoulli iid experiences with error proba b
#      48 """
#      49 if e < n:
#      50     v = np.array([
#      51         np.exp(
# ---> 52             binomial_log(n, j)
#      53             +j*np.log(b)
#      54             +(n-j)*np.log(1-b)) for j in range(e+1)])
#      55     return np.sum(v)
#      56 elif e == n:
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:38, in binomial_log(n, j)
#      37 def binomial_log(n, j):
# ---> 38     return gammaln(n + 1) - gammaln(j + 1) - gammaln(n - j + 1)
#
# KeyboardInterrupt:

# %% [markdown]
# __Comment__ : here one can observe that
# * risk-coverage curves do not really change as class imbalance increases

# %% [markdown]
# ## <font color = 'yellow'> 2. __FN/FP proportions control__
# Dichotomy search for upper bound

# %% [markdown]
# ### <font color = 'orange'> 2.1. __FP proportion control__

# %% [markdown]
# #### <font color = 'violet'> 2.1.1. Risk coverage trade-offs

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, 
                         metric='FP', mode='dicho')
display(results)
metric_plots(results, ylabel='FP proportion', xlim1=[0,1], xlim2=[0.4,1], ylim=[0,max(results.metric_bound)])
# Out:
#     metric_target  metric_bound  theta_star  train_metric  train_coverage  \
# 0           0.013      0.014225    0.987760      0.001550        0.138234
# 1           0.016      0.013718    0.987021      0.001495        0.143378
# 2           0.018      0.016899    0.969826      0.006061        0.247535
# 3           0.022      0.022232    0.941155      0.011751        0.364766
# 4           0.025      0.024778    0.915177      0.014627        0.439563
# 5           0.030      0.030218    0.876379      0.020000        0.535791
# 6           0.035      0.034924    0.838505      0.024538        0.602658
# 7           0.041      0.040928    0.813683      0.030030        0.642306
# 8           0.047      0.047085    0.779245      0.035879        0.698886
# 9           0.055      0.054829    0.725917      0.043296        0.767252
# 10          0.063      0.062788    0.642539      0.051167        0.862838
# 11          0.073      0.073168    0.583763      0.061078        0.922846
# 12          0.083      0.083054    0.522929      0.070601        0.980497
# 13          0.095      0.085373    0.501013      0.072883        0.999786
# 14          0.108      0.085373    0.501013      0.072883        0.999786
# 15          0.123      0.085373    0.501013      0.072883        0.999786
# 16          0.139      0.085373    0.501013      0.072883        0.999786
# 17          0.156      0.085373    0.501013      0.072883        0.999786
# 18          0.175      0.085373    0.501013      0.072883        0.999786
# 19          0.196      0.085373    0.501013      0.072883        0.999786
# 20          0.219      0.085373    0.501013      0.072883        0.999786
# 21          0.244      0.085373    0.501013      0.072883        0.999786
# 22          0.271      0.085373    0.501013      0.072883        0.999786
# 23          0.300      0.085373    0.501013      0.072883        0.999786
#
#     test_metric  test_coverage
# 0      0.003106       0.137961
# 1      0.003003       0.142674
# 2      0.007421       0.230934
# 3      0.012626       0.339332
# 4      0.021429       0.419880
# 5      0.027966       0.505570
# 6      0.031923       0.577121
# 7      0.034819       0.615253
# 8      0.035872       0.680805
# 9      0.044126       0.747644
# 10     0.054054       0.856041
# 11     0.060748       0.916881
# 12     0.069268       0.977292
# 13     0.075439       0.999572
# 14     0.075439       0.999572
# 15     0.075439       0.999572
# 16     0.075439       0.999572
# 17     0.075439       0.999572
# 18     0.075439       0.999572
# 19     0.075439       0.999572
# 20     0.075439       0.999572
# 21     0.075439       0.999572
# 22     0.075439       0.999572
# 23     0.075439       0.999572

# %% [markdown]
# __Comment__ : ~threefold increase of performance at the cost of -70% coverage
# 1) Best guaranteed performance (left) is ~2% of samples classified as FPs, cost is coverage =30%.
# 2) Baseline performance of classifier at 100% coverage would be ~10% of samples classified as FPs.

# %% [markdown]
# #### <font color = 'violet'> 2.1.2 Evolution of trade-offs as class imbalance increases

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, sgr_df, 
                                                   delta, mode='dicho', metric='FP')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='FP proportion', xlim1= [0, 1], xlim2= [0.4, 1],
                            ylim=[0,max(all_propor_dfs.metric_bound)])

# %% [markdown]
# __Comment__ : one can observe that here less 1s means
# * higher FP risk at fixed coverage (makes completely sense since there are relatively more 0s to commit mistakes on)
# * steeper risk/coverage curves, ie more FP risk improvement from the same amount of coverage renouncement
#
# __In other words, in this setting, higher class imbalance => Selection with Guaranteed FP Risk brings more benefits with the same amount of coverage renouncement__

# %% [markdown]
# ### <font color = 'orange'> 2.2. __FN proportion control__

# %% [markdown]
# #### <font color = 'violet'> 2.2.1. Risk coverage trade-offs

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, 
                         metric = 'FN', mode='dicho')
display(results)
metric_plots(results, ylabel='FN proportion', xlim1=[0,1], xlim2=[0.4,1], ylim=[0,max(results.metric_bound)])
# Out:
#     metric_target  metric_bound  theta_star  train_metric  train_coverage  \
# 0           0.018      0.018764    0.964641      0.007819        0.274111
# 1           0.022      0.022644    0.943125      0.011969        0.358123
# 2           0.025      0.025213    0.926615      0.014629        0.410201
# 3           0.030      0.029879    0.877650      0.019695        0.533219
# 4           0.035      0.034794    0.819909      0.024679        0.633948
# 5           0.041      0.040867    0.770423      0.030495        0.709816
# 6           0.047      0.047209    0.740443      0.036358        0.748607
# 7           0.055      0.055019    0.688293      0.043788        0.812473
# 8           0.063      0.062840    0.652652      0.051134        0.850836
# 9           0.073      0.073120    0.590323      0.060996        0.917060
# 10          0.083      0.083031    0.538258      0.070494        0.966781
# 11          0.095      0.088820    0.501013      0.076099        0.999786
# 12          0.108      0.088820    0.501013      0.076099        0.999786
# 13          0.123      0.088820    0.501013      0.076099        0.999786
# 14          0.139      0.088820    0.501013      0.076099        0.999786
# 15          0.156      0.088820    0.501013      0.076099        0.999786
# 16          0.175      0.088820    0.501013      0.076099        0.999786
# 17          0.196      0.088820    0.501013      0.076099        0.999786
# 18          0.219      0.088820    0.501013      0.076099        0.999786
# 19          0.244      0.088820    0.501013      0.076099        0.999786
# 20          0.271      0.088820    0.501013      0.076099        0.999786
# 21          0.300      0.088820    0.501013      0.076099        0.999786
#
#     test_metric  test_coverage
# 0      0.013582       0.252356
# 1      0.011613       0.332048
# 2      0.017817       0.384747
# 3      0.020443       0.502999
# 4      0.031095       0.606255
# 5      0.046943       0.693659
# 6      0.050529       0.729220
# 7      0.056391       0.797772
# 8      0.063195       0.847472
# 9      0.071193       0.908740
# 10     0.084004       0.958869
# 11     0.092585       0.999572
# 12     0.092585       0.999572
# 13     0.092585       0.999572
# 14     0.092585       0.999572
# 15     0.092585       0.999572
# 16     0.092585       0.999572
# 17     0.092585       0.999572
# 18     0.092585       0.999572
# 19     0.092585       0.999572
# 20     0.092585       0.999572
# 21     0.092585       0.999572

# %% [markdown]
# #### <font color = 'violet'> 2.2.2 Evolution of trade-offs as class imbalance increases

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, sgr_df,
                                                   delta, mode='dicho', metric='FN')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='FN proportion', xlim1= [0, 1], xlim2= [0.4, 1],
                            ylim=[0,max(all_propor_dfs.metric_bound)])

# %% [markdown]
# ## <font color = 'yellow'> 3. __Specific metrics control__

# %% [markdown]
# ### <font color = 'orange'> 3.1. __FPR control__

# %% [markdown]
# #### <font color = 'violet'> 3.1.1. Risk coverage trade-offs

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, 
                         metric = 'FPR', mode='greedy', steps=greedy_search_steps_num)
display(results)
metric_plots(results, ylabel='FPR', xlim1=[0,1], xlim2=[0.4,1], ylim=[0,max(results.metric_bound)])
# Out:
#     metric_target  metric_bound  theta_star  train_metric  train_coverage  \
# 0           0.041      0.040052    0.949066      0.014525        0.331976
# 1           0.047      0.040052    0.949066      0.014525        0.331976
# 2           0.055      0.051266    0.918507      0.024434        0.430776
# 3           0.063      0.063494    0.877762      0.035821        0.532576
# 4           0.073      0.072297    0.847203      0.043686        0.587870
# 5           0.083      0.082907    0.826831      0.052356        0.621303
# 6           0.095      0.095835    0.796272      0.063570        0.671453
# 7           0.108      0.107108    0.765713      0.073648        0.716031
# 8           0.123      0.122922    0.704595      0.088282        0.793613
# 9           0.139      0.136361    0.643477      0.100691        0.860909
# 10          0.156      0.156018    0.592546      0.118415        0.914916
# 11          0.175      0.174073    0.541614      0.134761        0.963781
# 12          0.196      0.187185    0.500869      0.146805        1.000000
# 13          0.219      0.187185    0.500869      0.146805        1.000000
# 14          0.244      0.187185    0.500869      0.146805        1.000000
# 15          0.271      0.187185    0.500869      0.146805        1.000000
# 16          0.300      0.187185    0.500869      0.146805        1.000000
#
#     test_metric  test_coverage
# 0      0.017699       0.314910
# 1      0.017699       0.314910
# 2      0.034843       0.413453
# 3      0.048673       0.502999
# 4      0.054201       0.559983
# 5      0.061697       0.595973
# 6      0.064516       0.649957
# 7      0.071348       0.701371
# 8      0.088727       0.774207
# 9      0.103113       0.854756
# 10     0.117159       0.905313
# 11     0.131810       0.956298
# 12     0.148148       0.999572
# 13     0.148148       0.999572
# 14     0.148148       0.999572
# 15     0.148148       0.999572
# 16     0.148148       0.999572

# %% [markdown]
# #### <font color = 'violet'> 3.1.2. Evolution of trade-offs as class imbalance increases

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, 
                                                   sgr_df, delta, mode='greedy',
                                                   greedy_search_steps_num=greedy_search_steps_num, 
                                                   metric='FPR')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='FPR', xlim1= [0, 1], xlim2= [0.4, 1],
                            ylim=[0,max(all_propor_dfs.metric_bound)])

# %% [markdown]
# ### <font color = 'orange'> 3.2. __FNR control__

# %% [markdown]
# #### <font color = 'violet'> 3.2.1. Risk coverage trade-offs

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, 
                         metric = 'FNR', mode='greedy', steps=greedy_search_steps_num)
display(results)
metric_plots(results, ylabel='FNR', xlim1=[0,1], xlim2=[0.4,1], ylim=[0,max(results.metric_bound)])
# Out:
#     metric_target  metric_bound  theta_star  train_metric  train_coverage  \
# 0           0.073      0.073711    0.887948      0.038853        0.508358
# 1           0.083      0.081965    0.837017      0.048909        0.605015
# 2           0.095      0.095541    0.775899      0.062460        0.702100
# 3           0.108      0.107764    0.755527      0.072948        0.731462
# 4           0.123      0.121100    0.694409      0.085886        0.803901
# 5           0.139      0.138949    0.653664      0.102041        0.849979
# 6           0.156      0.154551    0.602732      0.116491        0.902057
# 7           0.175      0.172345    0.561987      0.132880        0.944278
# 8           0.196      0.191681    0.500869      0.151064        1.000000
# 9           0.219      0.191681    0.500869      0.151064        1.000000
# 10          0.244      0.191681    0.500869      0.151064        1.000000
# 11          0.271      0.191681    0.500869      0.151064        1.000000
# 12          0.300      0.191681    0.500869      0.151064        1.000000
#
#     test_metric  test_coverage
# 0      0.046316       0.484576
# 1      0.055462       0.580120
# 2      0.099727       0.684662
# 3      0.102597       0.712082
# 4      0.114679       0.790917
# 5      0.129707       0.845758
# 6      0.142717       0.897172
# 7      0.160112       0.939589
# 8      0.188646       0.999572
# 9      0.188646       0.999572
# 10     0.188646       0.999572
# 11     0.188646       0.999572
# 12     0.188646       0.999572

# %% [markdown]
# #### <font color = 'violet'> 3.2.2. Evolution of trade-offs as class imbalance increases

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, 
                                                   sgr_df, delta, mode='greedy',
                                                   greedy_search_steps_num=greedy_search_steps_num,
                                                   metric='FNR')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='FNR', xlim1= [0, 1], xlim2= [0.4, 1],
                            ylim=[0,max(all_propor_dfs.metric_bound)])

# %%
all_propor_dfs
# Out:
#      metric_target  metric_bound  theta_star  train_metric  train_coverage  \
# 0            0.095      0.094421    0.765331      0.027027        0.750630
# 1            0.108      0.094421    0.765331      0.027027        0.750630
# 2            0.123      0.118479    0.714316      0.050000        0.800588
# 3            0.139      0.118479    0.714316      0.050000        0.800588
# 4            0.156      0.142307    0.693910      0.069767        0.827036
# ..             ...           ...         ...           ...             ...
# 161          0.196      0.196159    0.541614      0.153432        0.959280
# 162          0.219      0.211137    0.500869      0.167665        1.000000
# 163          0.244      0.211137    0.500869      0.167665        1.000000
# 164          0.271      0.211137    0.500869      0.167665        1.000000
# 165          0.300      0.211137    0.500869      0.167665        1.000000
#
#      test_metric  test_coverage  proportion_1
# 0       0.000000       0.739094          0.01
# 1       0.000000       0.739094          0.01
# 2       0.000000       0.806208          0.01
# 3       0.000000       0.806208          0.01
# 4       0.083333       0.825503          0.01
# ..           ...            ...           ...
# 161     0.142730       0.965296          0.50
# 162     0.154710       0.999572          0.50
# 163     0.154710       0.999572          0.50
# 164     0.154710       0.999572          0.50
# 165     0.154710       0.999572          0.50
#
# [166 rows x 8 columns]

# %% [markdown]
# ### <font color = 'orange'> 3.3. __PPV control__

# %% [markdown]
# #### <font color = 'violet'> 3.3.1. Risk coverage trade-offs

# %%
metric_targets=[i/1000 for i in integers_log_spacing(700,1000)]

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, 
                         metric = 'PPV', mode='greedy', steps=greedy_search_steps_num)
display(results)
metric_plots(results, ylabel='PPV', xlim1=[0,1], xlim2=[0.4,1], ylim=[0.8, max(results.train_metric)])
# Out:
#     metric_target  metric_bound  theta_star  train_metric  train_coverage  \
# 0           0.700      0.814471    0.500869      0.854390        1.000000
# 1           0.730      0.814471    0.500869      0.854390        1.000000
# 2           0.757      0.814471    0.500869      0.854390        1.000000
# 3           0.782      0.814471    0.500869      0.854390        1.000000
# 4           0.805      0.814471    0.500869      0.854390        1.000000
# 5           0.827      0.826097    0.541614      0.865359        0.963781
# 6           0.846      0.847374    0.612918      0.885341        0.891342
# 7           0.864      0.864153    0.674036      0.901209        0.827690
# 8           0.880      0.879299    0.745340      0.916175        0.744106
# 9           0.895      0.895108    0.796272      0.931171        0.671453
# 10          0.908      0.913256    0.837017      0.947526        0.605015
# 11          0.920      0.920410    0.867576      0.955199        0.548864
# 12          0.931      0.934059    0.918507      0.970033        0.430776
#
#     test_metric  test_coverage
# 0      0.840724       0.999572
# 1      0.840724       0.999572
# 2      0.840724       0.999572
# 3      0.840724       0.999572
# 4      0.840724       0.999572
# 5      0.858089       0.956298
# 6      0.875506       0.887318
# 7      0.894091       0.815767
# 8      0.908031       0.724079
# 9      0.920000       0.649957
# 10     0.927393       0.580120
# 11     0.929104       0.524422
# 12     0.949109       0.413453

# %% [markdown]
# #### <font color = 'violet'> 3.3.2. Evolution of trade-offs as class imbalance increases

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, 
                                                   sgr_df, delta, mode='greedy',
                                                   greedy_search_steps_num=greedy_search_steps_num,
                                                   metric='PPV')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='PPV', xlim1= [0.3, 1], xlim2= [0.4, 1],
                            ylim=[0.6,max(all_propor_dfs.test_metric)])

# %% [markdown]
# ### <font color = 'orange'> 3.4. __SE control__

# %% [markdown]
# #### <font color = 'violet'> 3.4.1. Risk coverage trade-offs

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, 
                         metric = 'SE', mode='greedy', steps=greedy_search_steps_num)
display(results)
metric_plots(results, ylabel='SE', xlim1=[0,1], xlim2=[0.4,1], ylim=[0.8,max(results.train_metric)])
# Out:
#     metric_target  metric_bound  theta_star  train_metric  train_coverage  \
# 0           0.700      0.808319    0.500869      0.848936        1.000000
# 1           0.730      0.808319    0.500869      0.848936        1.000000
# 2           0.757      0.808319    0.500869      0.848936        1.000000
# 3           0.782      0.808319    0.500869      0.848936        1.000000
# 4           0.805      0.808319    0.500869      0.848936        1.000000
# 5           0.827      0.827655    0.561987      0.867120        0.944278
# 6           0.846      0.845449    0.602732      0.883509        0.902057
# 7           0.864      0.865633    0.663850      0.902185        0.838405
# 8           0.880      0.881646    0.704595      0.916667        0.793613
# 9           0.895      0.901090    0.765713      0.934498        0.716031
# 10          0.908      0.907312    0.806458      0.941176        0.655808
# 11          0.920      0.919650    0.847203      0.953052        0.587870
# 12          0.931      0.930391    0.938880      0.972037        0.370767
#
#     test_metric  test_coverage
# 0      0.811354       0.999572
# 1      0.811354       0.999572
# 2      0.811354       0.999572
# 3      0.811354       0.999572
# 4      0.811354       0.999572
# 5      0.839888       0.939589
# 6      0.857283       0.897172
# 7      0.874464       0.829477
# 8      0.885748       0.774207
# 9      0.897878       0.701371
# 10     0.916159       0.629392
# 11     0.949033       0.559983
# 12     0.971246       0.346187

# %% [markdown]
# #### <font color = 'violet'> 3.4.2. Evolution of trade-offs as class imbalance increases

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, 
                                                   sgr_df, delta, mode='greedy',
                                                   greedy_search_steps_num=greedy_search_steps_num,
                                                   metric='SE')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='SE', xlim1= [0, 1], xlim2= [0.4, 1],
                            ylim=[0.6,max(all_propor_dfs.test_metric)])

# %% [markdown]
# ### <font color = 'orange'> 3.5. __SP control__

# %% [markdown]
# #### <font color = 'violet'> 3.5.1. Risk coverage trade-offs

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, 
                         metric = 'SP', mode='greedy', steps=greedy_search_steps_num)
display(results)
metric_plots(results, ylabel='SP', xlim1=[0,1], xlim2=[0.4,1], ylim=[0.8,max(results.train_metric)])
# Out:
#     metric_target  metric_bound  theta_star  train_metric  train_coverage  \
# 0           0.700      0.812815    0.500869      0.853195        1.000000
# 1           0.730      0.812815    0.500869      0.853195        1.000000
# 2           0.757      0.812815    0.500869      0.853195        1.000000
# 3           0.782      0.812815    0.500869      0.853195        1.000000
# 4           0.805      0.812815    0.500869      0.853195        1.000000
# 5           0.827      0.830227    0.551801      0.869096        0.955637
# 6           0.846      0.846716    0.602732      0.884126        0.902057
# 7           0.864      0.863639    0.643477      0.899309        0.860909
# 8           0.880      0.880680    0.724968      0.915227        0.768324
# 9           0.895      0.898148    0.775899      0.930873        0.702100
# 10          0.908      0.907274    0.806458      0.939299        0.655808
# 11          0.920      0.923886    0.837017      0.953146        0.605015
# 12          0.931      0.933455    0.867576      0.961538        0.548864
# 13          0.941      0.943664    0.908321      0.971186        0.458208
# 14          0.949      0.948734    0.918507      0.975566        0.430776
# 15          0.957      0.959948    0.949066      0.985475        0.331976
#
#     test_metric  test_coverage
# 0      0.851852       0.999572
# 1      0.851852       0.999572
# 2      0.851852       0.999572
# 3      0.851852       0.999572
# 4      0.851852       0.999572
# 5      0.869604       0.949443
# 6      0.884045       0.897172
# 7      0.896887       0.854756
# 8      0.917204       0.749357
# 9      0.933025       0.684662
# 10     0.937269       0.629392
# 11     0.942029       0.580120
# 12     0.945792       0.524422
# 13     0.958814       0.442588
# 14     0.965157       0.413453
# 15     0.982301       0.314910

# %% [markdown]
# #### <font color = 'violet'> 3.5.2. Evolution of trade-offs as class imbalance increases

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, 
                                                   sgr_df, delta, mode='greedy',
                                                   greedy_search_steps_num=greedy_search_steps_num,
                                                   metric='SP')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='SP', xlim1= [0, 1], xlim2= [0.4, 1],
                            ylim=[0.8,max(all_propor_dfs.test_metric)])
