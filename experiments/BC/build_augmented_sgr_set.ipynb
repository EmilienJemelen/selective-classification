# %%
import sys
import os
current_dir = os.getcwd()
root_path = os.path.abspath(os.path.join(current_dir, '..', '..'))
if root_path not in sys.path:
    sys.path.append(root_path)
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,accuracy_score
import pickle
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn import datasets
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import kagglehub
from scipy.io import arff
from imblearn.under_sampling import RandomUnderSampler
from python_scripts.preprocessing import *
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# Loading dataset : https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data

# %%
# Download latest version
path = kagglehub.dataset_download("uciml/breast-cancer-wisconsin-data")
print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.11), please consider upgrading to the latest version (0.3.12).
# Path to dataset files: C:\Users\ejeme\.cache\kagglehub\datasets\uciml\breast-cancer-wisconsin-data\versions\2

# %%
df = pd.read_csv('C:/Users/ejeme/Documents/breast-cancer.csv')
df['diagnosis'].replace({'M':1, 'B':0}, inplace=True)
df.drop(['id','Unnamed: 32'], axis=1, inplace=True)
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
print(df.shape)
print('Proportion of 1s:', np.round(df.diagnosis.sum()/df.shape[0],2))
# Out:
# (569, 31)
# Proportion of 1s: 0.37

# %%
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(df)

# Step 2: Initialize the CTGAN synthesizer with metadata
model = CTGANSynthesizer(metadata, epochs=500)
model.fit(df)

# Sample synthetic data
synthetic_dataset = model.sample(100000)
synthetic_dataset = generate_imbalanced_datasets(synthetic_dataset, proportions =[df.diagnosis.sum()/df.shape[0]], label_col='diagnosis')[0]

# %% [markdown]
# #### some preprocessing

# %%
X = synthetic_dataset.drop(['diagnosis'], axis=1)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# If you want a DataFrame back
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
Y = synthetic_dataset.diagnosis

# %%
Y.sum()/len(Y)
# Out:
# np.float64(0.41609059334621357)

# %%
# split
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.5, random_state=0, stratify=Y)

# %% [markdown]
# ## <font color='yellow'> logistic regression

# %%
model = LogisticRegression(random_state=0, max_iter=100)
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
# On test set after model selection
test_pred = model.predict(X_test)
print(classification_report(Y_test, test_pred))
print('Test Accuracy:', accuracy_score(Y_test, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     26143
#            1       0.93      0.93      0.93     18629
#
#     accuracy                           0.94     44772
#    macro avg       0.94      0.94      0.94     44772
# weighted avg       0.94      0.94      0.94     44772
#
# Test Accuracy: 0.9434691324935227

# %% [markdown]
# ### Retrieving $\kappa_f$ confidence function

# %%
y_true = Y_test
y_pred = test_pred
kappa = model.predict_proba(X_test).max(axis=1)
plt.plot(sorted(kappa))

# %%
sgr_df = pd.DataFrame({'y_true': y_true,
                       'y_pred': y_pred,
                       'kappa': kappa}).sort_values('kappa')
sgr_df
# Out:
#        y_true  y_pred     kappa
# 74679       1       1  0.500034
# 58475       1       0  0.500199
# 17470       0       1  0.500205
# 4686        1       1  0.500320
# 1050        1       0  0.500505
# ...       ...     ...       ...
# 52468       1       1  1.000000
# 17318       1       1  1.000000
# 39331       1       1  1.000000
# 26979       1       1  1.000000
# 68637       1       1  1.000000
#
# [44772 rows x 3 columns]

# %%
pickle.dump(sgr_df, open('sgr_set_log_reg_augmented','wb'))
