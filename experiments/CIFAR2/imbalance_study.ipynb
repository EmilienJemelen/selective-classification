# %%
import os
import sys
current_dir = os.getcwd()
root_path = os.path.abspath(os.path.join(current_dir, '..', '..'))
if root_path not in sys.path:
    sys.path.append(root_path)
import torch
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import torch.nn as nn
import numpy as np
import pickle
import pandas as pd
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import math
import scipy.special
import random as rd
import matplotlib.pyplot as plt
import torch.nn.functional as F
import torchvision.models as models
from torchvision.models import VGG16_Weights
from tqdm import tqdm
import torch.optim.lr_scheduler as lr_scheduler
from python_scripts.sgr_utils import *
from python_scripts.plotting import *
from scipy.special import gammaln
import warnings
warnings.filterwarnings("ignore")
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150

print("GPU Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# GPU Available: True
# GPU Name: NVIDIA GeForce RTX 4060

# %% [markdown]
# #### Choose the sgr set you want to use :
# * must be data the model did not see at training
# * first column : __y_true__ $\in \{0,1\}$ are the samples labels
# * second column : __y_pred__ are the predicted class of samples ($\in \{0,1\}$ too)
# * third column : __kappa_f__ is confidence function for each sample, $\in \mathbb{R}_+$

# %%
sgr_df = pickle.load(open('sgr_set_cnn','rb')) 
print(sgr_df.shape)
print('Propotion of 1s: ', np.round(sgr_df.y_true.sum()/sgr_df.shape[0],2))
sgr_df.head()
# Out:
# (40000, 3)
# Propotion of 1s:  0.1
#    y_true  y_pred     kappa
# 0     0.0     0.0  0.991906
# 1     0.0     0.0  0.739398
# 2     0.0     0.0  0.959858
# 3     0.0     0.0  0.944551
# 4     0.0     0.0  0.934431

# %%
delta = 0.001
greedy_search_steps_num = 50 # increase number of search steps for more precise metrics bounds
metric_targets=[i/1000 for i in integers_exp_spacing(5,300)]
proportions_1 = np.linspace(0.01,0.5,15) # for classes imbalance impact study

# %% [markdown]
# ## <font color = 'yellow'> 1. __0/1 risk (Evolution of trade-offs as class imbalance increases)__
# Dichotomy search for upper bound

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, 
                                                   sgr_df, delta, mode='dicho', 
                                                   metric='standard')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='0/1 risk', xlim1= [min(all_propor_dfs.test_coverage), 1], xlim2= [min(all_propor_dfs.theta_star), 1],
                            ylim=[0,max(all_propor_dfs.metric_bound)], show_left_legend=True)

# %% [markdown]
# ## <font color = 'yellow'> 2. __FPP/FNP__
# Dichotomy search for upper bound

# %% [markdown]
# ### <font color = 'orange'> 2.1. __FPP__

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, sgr_df, 
                                                   delta, mode='dicho', metric='FP')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='FP proportion', xlim1= [min(all_propor_dfs.test_coverage), 1], xlim2= [min(all_propor_dfs.theta_star), 1],
                            ylim=[0,max(all_propor_dfs.metric_bound)], show_left_legend=True)

# %% [markdown]
# ### <font color = 'orange'> 2.2. __FNP__

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, sgr_df,
                                                   delta, mode='dicho', metric='FN')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='FN proportion', xlim1= [min(all_propor_dfs.test_coverage), 1], xlim2= [min(all_propor_dfs.theta_star), 1],
                            ylim=[0,max(all_propor_dfs.metric_bound)], show_left_legend=True)

# %% [markdown]
# ## <font color = 'yellow'> __3. Conditional metrics__

# %% [markdown]
# ### <font color = 'orange'> 3.1. __FPR__

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, 
                                                   sgr_df, delta, mode='greedy',
                                                   greedy_search_steps_num=greedy_search_steps_num, 
                                                   metric='FPR')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='FPR', xlim1= [min(all_propor_dfs.test_coverage), 1], xlim2= [min(all_propor_dfs.theta_star), 1],
                            ylim=[0,max(all_propor_dfs.metric_bound)], show_left_legend=True)

# %% [markdown]
# ### <font color = 'orange'> 3.2. __FNR__

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, 
                                                   sgr_df, delta, mode='greedy',
                                                   greedy_search_steps_num=greedy_search_steps_num,
                                                   metric='FNR')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='FNR', xlim1= [min(all_propor_dfs.test_coverage), 1], xlim2= [min(all_propor_dfs.theta_star), 1],
                            ylim=[0,max(all_propor_dfs.metric_bound)], show_left_legend=True)

# %% [markdown]
# ### <font color = 'orange'> 3.3. __PPV__

# %%
metric_targets=[i/1000 for i in integers_log_spacing(700,1000)]

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, 
                                                   sgr_df, delta, mode='greedy',
                                                   greedy_search_steps_num=greedy_search_steps_num,
                                                   metric='PPV')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='PPV', xlim1= [min(all_propor_dfs.test_coverage), 1], xlim2= [min(all_propor_dfs.theta_star), 1],
                            ylim=[min(all_propor_dfs.metric_bound),max(all_propor_dfs.test_metric)], show_left_legend=True)

# %% [markdown]
# ### <font color = 'orange'> 3.4. __SE__

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, 
                                                   sgr_df, delta, mode='greedy',
                                                   greedy_search_steps_num=greedy_search_steps_num,
                                                   metric='SE')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='SE', xlim1= [min(all_propor_dfs.test_coverage), 1], xlim2= [min(all_propor_dfs.theta_star), 1],
                            ylim=[min(all_propor_dfs.metric_bound),max(all_propor_dfs.test_metric)],
                            show_left_legend=True)

# %% [markdown]
# ### <font color = 'orange'> 3.5. __SP control__

# %%
all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets, 
                                                   sgr_df, delta, mode='greedy',
                                                   greedy_search_steps_num=greedy_search_steps_num,
                                                   metric='SP')
metric_plots_with_imbalance(all_propor_dfs, proportions_1,
                            ylabel='SP', xlim1= [min(all_propor_dfs.test_coverage), 1], xlim2= [min(all_propor_dfs.theta_star), 1],
                            ylim=[0.8,max(all_propor_dfs.test_metric)], show_left_legend=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 all_propor_dfs = SGR_at_targets_on_imbalanced_sets(proportions_1, metric_targets,
#       2                                                    sgr_df, delta, mode='greedy',
#       3                                                    greedy_search_steps_num=greedy_search_steps_num,
#       4                                                    metric='SP')
#       5 metric_plots_with_imbalance(all_propor_dfs, proportions_1,
#       6                             ylabel='SP', xlim1= [min(all_propor_dfs.test_coverage), 1], xlim2= [min(all_propor_dfs.theta_star), 1],
#       7                             ylim=[0.8,max(all_propor_dfs.test_metric)], show_left_legend=True)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\sgr_utils.py:277, in SGR_at_targets_on_imbalanced_sets(proportions_of_1, metric_targets, sgr_df, delta, mode, greedy_search_steps_num, metric)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\sgr_utils.py:226, in SGR_at_targets(train_set, test_set, k, delta, metric_targets, metric, union, mode, steps)
#     223     raise ValueError('mode should be either "greedy" or "dicho"')
#     225 if sgr_dico != {}:
# --> 226     theta_star = sgr_dico['theta_star']
#     227     covered_test_set = test_set.loc[test_set.kappa > theta_star]
#     228     if covered_test_set.shape[0] > 0:
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\sgr_utils.py:191, in SGR_greedy_search(delta, r_star, Sn, metric, steps)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
#     [... skipping similar frames: B_star at line 77 (2 times)]
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
#     [... skipping similar frames: B_star at line 79 (4 times), B_star at line 77 (2 times)]
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:76, in B_star(delta, e, n, eps, b1, b2)
#      74 if abs(binom_sum(b,e,n) - delta) < eps:
#      75     return b
# ---> 76 elif binom_sum(b,e,n) <= delta - eps:
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#
# File c:\Users\ejeme\Documents\python_repos\SGR\python_scripts\math_utils.py:51, in binom_sum(b, e, n)
#      43 """
#      44 binomial sum of term b in [0,1]
#      45 with binomial coefs "j among n"
#      46 for j in 0,1,...,e
#      47 it is the proba of doing at most e errors among n Bernoulli iid experiences with error proba b
#      48 """
#      49 if e < n:
#      50     v = np.array([
# ---> 51         np.exp(
#      52             binomial_log(n, j)
#      53             +j*np.log(b)
#      54             +(n-j)*np.log(1-b)) for j in range(e+1)])
#      55     return np.sum(v)
#      56 elif e == n:
#
# KeyboardInterrupt:
