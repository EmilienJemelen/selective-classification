# %%
import os
import sys
current_dir = os.getcwd()
root_path = os.path.abspath(os.path.join(current_dir, '..', '..'))
if root_path not in sys.path:
    sys.path.append(root_path)
import torch
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import torch.nn as nn
import numpy as np
import pickle
import pandas as pd
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import math
import scipy.special
import random as rd
import matplotlib.pyplot as plt
import torch.nn.functional as F
import torchvision.models as models
from torchvision.models import VGG16_Weights
from tqdm import tqdm
import torch.optim.lr_scheduler as lr_scheduler
from python_scripts.sgr_utils import *
from python_scripts.plotting import *
from python_scripts.preprocessing import *
from scipy.special import gammaln
import warnings
warnings.filterwarnings("ignore")
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150

print("GPU Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# GPU Available: True
# GPU Name: NVIDIA GeForce RTX 4060

# %%
sgr_df = pickle.load(open('sgr_set_cnn_MCD','rb')) 
print(sgr_df.shape)
sgr_df.head()
# Out:
# (40000, 3)
#    y_true  y_pred     kappa
# 0     0.0       1  0.784600
# 1     0.0       0  0.868785
# 2     0.0       0  0.825379
# 3     0.0       0  0.974705
# 4     0.0       0  0.597470

# %%
print(sgr_df.y_true.sum()/sgr_df.shape[0])
# Out:
# 0.101

# %%
delta = 0.01

# %%
train_set = sgr_df.iloc[:3*int(len(sgr_df)/4)]
train_set = train_set.sort_values('kappa', ascending=True).reset_index(drop=True).copy()
test_set = sgr_df.iloc[3*int(len(sgr_df)/4):]

# %% [markdown]
# ### Joint evolution of metrics with respect to $\theta$

# %%
# Define color maps
color_map1 = {
    'standard': "#d51414",
    'FP': "#e5be12",
    'FN': "#27e21d",
    'FPR': "#403535",
    'FNR': "#1d3ae2"
}
label_map1 = {
    'standard': '0/1 risk',
    'FP': 'FPP',
    'FN': 'FNP',
    'FPR': 'FPR',
    'FNR': 'FNR'
}

color_map2 = {
    'SE': "#d51de2",
    'SP': "#16CEE2",
    'PPV': "#676767"
}

# Create subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 6))  # 1 row, 2 columns

# ----- First subplot -----
ax = axes[0]
for metric in ['standard', 'FP', 'FN', 'FPR', 'FNR']:
    color = color_map1[metric]
    
    thetas, bounds = bound_evo_w_theta(metric, train_set, delta, steps=50)
    ax.plot(thetas, bounds, color=color, label=label_map1[metric] + ' bound', linewidth=2)

    emp_metrics = []
    for theta in thetas:
        try:
            selected_set = test_set.loc[test_set.kappa >= theta].copy()
            emp_metrics.append(emp_metric(selected_set, metric=metric))
        except ValueError:
            emp_metrics.append(np.nan)

    ax.plot(thetas, emp_metrics, linestyle='--', color=color, label='Test ' + label_map1[metric], linewidth=2)

ax.set_ylim(0, 1)
ax.set_xlabel(r'$\theta$')
ax.set_ylabel('Metric')
ax.legend()
ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)

# ----- Second subplot -----
ax = axes[1]
for metric in ['PPV', 'SE', 'SP']:
    color = color_map2[metric]
    
    thetas, bounds = bound_evo_w_theta(metric, train_set, delta, steps=50)
    ax.plot(thetas, bounds, color=color, label=metric + ' bound', linewidth=2)

    emp_metrics = []
    for theta in thetas:
        try:
            selected_set = test_set.loc[test_set.kappa >= theta].copy()
            emp_metrics.append(emp_metric(selected_set, metric=metric))
        except ValueError:
            emp_metrics.append(np.nan)

    ax.plot(thetas, emp_metrics, linestyle='--', color=color, label='Test ' + metric, linewidth=2)

ax.set_ylim(0, 1)
ax.set_xlabel(r'$\theta$')
ax.legend()
ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Find best $\theta$ in the intersection of metrics $\theta$ regions, if non empty

# %%
metrics_and_targets = {'FNR' : 0.2,
                       'FPR' : 0.1}

# %%
joint_output = joint_control(metrics_and_targets, train_set, delta, plot=False)
joint_output
# Out:
# {'theta_intervals': [], 'best_theta': inf}

# %% [markdown]
# ### All reachable bounds for a couple of 2 metrics

# %%
metrics = ['standard', 'FP', 'FN', 'FPR',
           'FNR','PPV', 'SE','SP']

all_bounds = reachable_bounds(metrics, train_set, delta, steps=100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 4
#       1 metrics = ['standard', 'FP', 'FN', 'FPR',
#       2            'FNR','PPV', 'SE','SP']
# ----> 4 all_bounds = reachable_bounds(metrics, train_set, delta, steps=100)
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\sgr_utils.py:336, in reachable_bounds(metrics_list, Sn, delta, steps)
#     334 # metrics bounds with respect to thetas
#     335 for metric in metrics_list:
# --> 336     _, bounds = bound_evo_w_theta(metric, Sn, delta, steps=steps)
#     337     res_dico[metric] = bounds
#     339 return res_dico
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\sgr_utils.py:308, in bound_evo_w_theta(metric, Sn, delta, steps)
#     305 if (selected_errs_count==0):
#     306     break
# --> 308 b = B_star(delta,
#     309            selected_errs_count,
#     310            selected_samples.shape[0])
#     311 if b==1:
#     312     break
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
#     [... skipping similar frames: B_star at line 79 (2 times), B_star at line 77 (1 times)]
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
#     [... skipping similar frames: B_star at line 79 (2 times)]
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:76, in B_star(delta, e, n, eps, b1, b2)
#      74 if abs(binom_sum(b,e,n) - delta) < eps:
#      75     return b
# ---> 76 elif binom_sum(b,e,n) <= delta - eps:
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:53, in binom_sum(b, e, n)
#      43 """
#      44 binomial sum of term b in [0,1]
#      45 with binomial coefs "j among n"
#      46 for j in 0,1,...,e
#      47 it is the proba of doing at most e errors among n Bernoulli iid experiences with error proba b
#      48 """
#      49 if e < n:
#      50     v = np.array([
#      51         np.exp(
#      52             binomial_log(n, j)
# ---> 53             +j*np.log(b)
#      54             +(n-j)*np.log(1-b)) for j in range(e+1)])
#      55     return np.sum(v)
#      56 elif e == n:
#
# KeyboardInterrupt:

# %%
metric1 = 'FNR'
metric2 = 'FPR'

x = all_bounds[metric1]
y = all_bounds[metric2]
labels = list(zip(all_bounds['thetas'], all_bounds['coverages']))

plt.scatter(x=x, y=y, marker = '+')
plt.xlabel(metric1 + ' bound')
plt.ylabel(metric2 + ' bound')
plt.grid()

# Choose evenly spaced indices along the curve
num_labels = 40
indices = np.linspace(0, len(x) - 1, num=num_labels, dtype=int)

for j in indices:
    label = f'({labels[j][0]:.2f}, {labels[j][1]:.2f})'
    plt.annotate(label, (x[j], y[j]), textcoords="offset points", xytext=(5,5), ha='left', fontsize=8)

# Add a single legend-like text to explain the annotations
plt.text(0.02, 0.98, r'Curve ticks: ($\theta$, coverage)',
         transform=plt.gca().transAxes,
         fontsize=9, verticalalignment='top', horizontalalignment='left',
         bbox=dict(boxstyle="round,pad=0.3", facecolor="white", edgecolor="gray", alpha=0.7))

plt.xlim(min(x)*0.9,max(x)*1.1)
plt.ylim(min(y)*0.9,max(y)*1.1)
plt.show()
