# %%
import os
import sys
current_dir = os.getcwd()
root_path = os.path.abspath(os.path.join(current_dir, '..', '..'))
if root_path not in sys.path:
    sys.path.append(root_path)
import torch
import matplotlib.cm as cm
import matplotlib.colors as mcolors
import torch.nn as nn
import numpy as np
import pickle
import pandas as pd
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import math
import scipy.special
import random as rd
import matplotlib.pyplot as plt
import torch.nn.functional as F
import torchvision.models as models
from torchvision.models import VGG16_Weights
from tqdm import tqdm
import torch.optim.lr_scheduler as lr_scheduler
from python_scripts.sgr_utils import *
from python_scripts.plotting import *
from scipy.special import gammaln
import warnings
warnings.filterwarnings("ignore")
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 150

print("GPU Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# GPU Available: True
# GPU Name: NVIDIA GeForce RTX 4060

# %% [markdown]
# #### Choose the sgr set you want to use :
# * must be data the model did not see at training
# * first column : __y_true__ $\in \{0,1\}$ are the samples labels
# * second column : __y_pred__ are the predicted class of samples ($\in \{0,1\}$ too)
# * third column : __kappa_f__ is confidence function for each sample, $\in \mathbb{R}_+$

# %%
sgr_df = pickle.load(open('sgr_set_cnn_MCD','rb')) 
print(sgr_df.shape)
print('Propotion of 1s: ', np.round(sgr_df.y_true.sum()/sgr_df.shape[0],2))
sgr_df.head()
# Out:
# (40000, 3)
# Propotion of 1s:  0.1
#    y_true  y_pred     kappa
# 0     0.0     1.0 -0.007081
# 1     0.0     0.0 -0.003906
# 2     0.0     0.0 -0.000431
# 3     0.0     0.0 -0.000506
# 4     0.0     0.0 -0.005671

# %%
delta = 0.01
greedy_search_steps_num = 50 # increase number of search steps for more precise metrics bounds
metric_targets=[i/1000 for i in integers_exp_spacing(5,300)]

# %%
train_set = sgr_df.iloc[:3*int(len(sgr_df)/4)]
train_set = train_set.sort_values('kappa', ascending=True).reset_index(drop=True).copy()
test_set = sgr_df.iloc[3*int(len(sgr_df)/4):]

# %% [markdown]
# ## <font color = 'yellow'> 1. __0/1 risk__
# Dichotomy search for upper bound

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, mode='dicho')
display(results)
metric_plots(results, ylabel='0/1 risk', 
             xlim1=[0.9*min(results.test_coverage),1.1*max(results.test_coverage)], 
             xlim2=[0.9*min(results.theta_star),1.1*max(results.theta_star)], 
             ylim=[0.5*min(results.test_metric),1.1*max(results.metric_bound)])
# Out:
#     metric_target  metric_bound  theta_star  train_metric  train_coverage  \
# 0           0.041      0.040900   -0.000540      0.035110        0.208867
# 1           0.047      0.047119   -0.000728      0.041756        0.279400
# 2           0.055      0.055020   -0.000884      0.049735        0.333767
# 3           0.063      0.063048   -0.001041      0.057816        0.387433
# 4           0.073      0.072884   -0.001271      0.067741        0.459100
# 5           0.083      0.083046   -0.001498      0.077907        0.518567
# 6           0.095      0.095044   -0.001820      0.089899        0.584733
# 7           0.108      0.108040   -0.002227      0.102896        0.656000
# 8           0.123      0.122975   -0.002873      0.117844        0.738267
# 9           0.139      0.139023   -0.003801      0.133894        0.820300
# 10          0.156      0.156005   -0.005691      0.150899        0.910767
# 11          0.175      0.175004   -0.012322      0.169875        0.990333
# 12          0.196      0.177472   -0.028226      0.172339        0.999967
# 13          0.219      0.177472   -0.028226      0.172339        0.999967
# 14          0.244      0.177472   -0.028226      0.172339        0.999967
# 15          0.271      0.177472   -0.028226      0.172339        0.999967
# 16          0.300      0.177472   -0.028226      0.172339        0.999967
#
#     test_metric  test_coverage
# 0      0.038999         0.2077
# 1      0.042622         0.2792
# 2      0.049704         0.3380
# 3      0.057084         0.3889
# 4      0.070586         0.4576
# 5      0.080310         0.5155
# 6      0.094872         0.5850
# 7      0.109241         0.6536
# 8      0.126728         0.7378
# 9      0.140475         0.8215
# 10     0.157005         0.9108
# 11     0.173465         0.9904
# 12     0.175818         0.9999
# 13     0.175818         0.9999
# 14     0.175818         0.9999
# 15     0.175818         0.9999
# 16     0.175818         0.9999

# %% [markdown]
# ## <font color = 'yellow'> 2. __FPP/FNP__
# Dichotomy search for upper bound

# %% [markdown]
# ### <font color = 'orange'> 2.1. __FPP__

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, 
                         metric='FP', mode='dicho')
display(results)
metric_plots(results, ylabel='FP proportion',
             xlim1=[0.9*min(results.test_coverage),1.1*max(results.test_coverage)], 
             xlim2=[0.9*min(results.theta_star),1.1*max(results.theta_star)], 
             ylim=[0.5*min(results.test_metric),1.1*max(results.metric_bound)])
# Out:
#     metric_target  metric_bound  theta_star  train_metric  train_coverage  \
# 0           0.035      0.035049   -0.000694      0.030288        0.266333
# 1           0.041      0.041022   -0.000854      0.036352        0.322767
# 2           0.047      0.047042   -0.001027      0.042459        0.382333
# 3           0.055      0.055034   -0.001226      0.050460        0.445900
# 4           0.063      0.063009   -0.001428      0.058414        0.502167
# 5           0.073      0.073047   -0.001696      0.068387        0.560533
# 6           0.083      0.082965   -0.001960      0.078235        0.611833
# 7           0.095      0.094981   -0.002451      0.090234        0.686733
# 8           0.108      0.108044   -0.003157      0.103288        0.767433
# 9           0.123      0.122953   -0.004350      0.118184        0.854600
# 10          0.139      0.139019   -0.006964      0.134232        0.941900
# 11          0.156      0.152027   -0.028226      0.147205        0.999967
# 12          0.175      0.152027   -0.028226      0.147205        0.999967
# 13          0.196      0.152027   -0.028226      0.147205        0.999967
# 14          0.219      0.152027   -0.028226      0.147205        0.999967
# 15          0.244      0.152027   -0.028226      0.147205        0.999967
# 16          0.271      0.152027   -0.028226      0.147205        0.999967
# 17          0.300      0.152027   -0.028226      0.147205        0.999967
#
#     test_metric  test_coverage
# 0      0.032756         0.2656
# 1      0.037309         0.3270
# 2      0.043354         0.3852
# 3      0.053567         0.4443
# 4      0.063438         0.4997
# 5      0.075701         0.5601
# 6      0.082540         0.6094
# 7      0.098337         0.6854
# 8      0.113281         0.7680
# 9      0.126873         0.8544
# 10     0.142993         0.9441
# 11     0.153515         0.9999
# 12     0.153515         0.9999
# 13     0.153515         0.9999
# 14     0.153515         0.9999
# 15     0.153515         0.9999
# 16     0.153515         0.9999
# 17     0.153515         0.9999

# %% [markdown]
# ### <font color = 'orange'> 2.2. __FNP__

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, 
                         metric = 'FN', mode='dicho')
display(results)
metric_plots(results, ylabel='FN proportion',
             xlim1=[0.9*min(results.test_coverage),1.1*max(results.test_coverage)], 
             xlim2=[0.9*min(results.theta_star),1.1*max(results.theta_star)], 
             ylim=[0.5*min(results.test_metric),1.1*max(results.metric_bound)])
# Out:
#     metric_target  metric_bound  theta_star  train_metric  train_coverage  \
# 0           0.010      0.010122   -0.000489      0.007071        0.188567
# 1           0.011      0.010881   -0.000518      0.007811        0.200567
# 2           0.013      0.012985   -0.000698      0.010077        0.267933
# 3           0.016      0.015978   -0.000989      0.013231        0.370333
# 4           0.018      0.018013   -0.001314      0.015426        0.471067
# 5           0.022      0.022006   -0.002847      0.019718        0.735367
# 6           0.025      0.024979   -0.005350      0.022777        0.900033
# 7           0.030      0.027317   -0.028226      0.025134        0.999967
# 8           0.035      0.027317   -0.028226      0.025134        0.999967
# 9           0.041      0.027317   -0.028226      0.025134        0.999967
# 10          0.047      0.027317   -0.028226      0.025134        0.999967
# 11          0.055      0.027317   -0.028226      0.025134        0.999967
# 12          0.063      0.027317   -0.028226      0.025134        0.999967
# 13          0.073      0.027317   -0.028226      0.025134        0.999967
# 14          0.083      0.027317   -0.028226      0.025134        0.999967
# 15          0.095      0.027317   -0.028226      0.025134        0.999967
# 16          0.108      0.027317   -0.028226      0.025134        0.999967
# 17          0.123      0.027317   -0.028226      0.025134        0.999967
# 18          0.139      0.027317   -0.028226      0.025134        0.999967
# 19          0.156      0.027317   -0.028226      0.025134        0.999967
# 20          0.175      0.027317   -0.028226      0.025134        0.999967
# 21          0.196      0.027317   -0.028226      0.025134        0.999967
# 22          0.219      0.027317   -0.028226      0.025134        0.999967
# 23          0.244      0.027317   -0.028226      0.025134        0.999967
# 24          0.271      0.027317   -0.028226      0.025134        0.999967
# 25          0.300      0.027317   -0.028226      0.025134        0.999967
#
#     test_metric  test_coverage
# 0      0.009033         0.1882
# 1      0.009567         0.1986
# 2      0.010479         0.2672
# 3      0.012577         0.3737
# 4      0.014088         0.4685
# 5      0.018524         0.7342
# 6      0.020051         0.8977
# 7      0.022302         0.9999
# 8      0.022302         0.9999
# 9      0.022302         0.9999
# 10     0.022302         0.9999
# 11     0.022302         0.9999
# 12     0.022302         0.9999
# 13     0.022302         0.9999
# 14     0.022302         0.9999
# 15     0.022302         0.9999
# 16     0.022302         0.9999
# 17     0.022302         0.9999
# 18     0.022302         0.9999
# 19     0.022302         0.9999
# 20     0.022302         0.9999
# 21     0.022302         0.9999
# 22     0.022302         0.9999
# 23     0.022302         0.9999
# 24     0.022302         0.9999
# 25     0.022302         0.9999

# %% [markdown]
# ## <font color = 'yellow'> __3. Conditional metrics__

# %% [markdown]
# ### <font color = 'orange'> 3.1. __FPR__

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, 
                         metric = 'FPR', mode='greedy', steps=greedy_search_steps_num)
display(results)
metric_plots(results, ylabel='FPR', 
             xlim1=[0.9*min(results.test_coverage),1.1*max(results.test_coverage)], 
             xlim2=[0.9*min(results.theta_star),1.1*max(results.theta_star)], 
             ylim=[0.5*min(results.test_metric),1.1*max(results.metric_bound)])

# %% [markdown]
# ### <font color = 'orange'> 3.2. __FNR__

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, 
                         metric = 'FNR', mode='greedy', steps=greedy_search_steps_num)
display(results)
metric_plots(results, ylabel='FNR', 
             xlim1=[0.9*min(results.test_coverage),1.1*max(results.test_coverage)], 
             xlim2=[0.9*min(results.theta_star),1.1*max(results.theta_star)], 
             ylim=[0.5*min(results.test_metric),1.1*max(results.metric_bound)])
# Out:
#    metric_target  metric_bound  theta_star  train_metric  train_coverage  \
# 0          0.271      0.271320   -0.002313      0.190970        0.668500
# 1          0.300      0.298736   -0.008672      0.236949        0.966133
#
#    test_metric  test_coverage
# 0     0.184514         0.6661
# 1     0.232816         0.9674

# %% [markdown]
# ### <font color = 'orange'> 3.3. __PPV__

# %%
metric_targets=[i/100 for i in integers_log_spacing(20,100)]

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, 
                         metric = 'PPV', mode='greedy', steps=greedy_search_steps_num)
display(results)
metric_plots(results, ylabel='PPV', 
             xlim1=[0.9*min(results.test_coverage),1.1*max(results.test_coverage)], 
             xlim2=[0.9*min(results.theta_star),1.1*max(results.theta_star)], 
             ylim=[0.5*min(results.metric_bound),1.1*max(results.train_metric)])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
#       2                          delta=delta, metric_targets=metric_targets,
#       3                          metric = 'PPV', mode='greedy', steps=greedy_search_steps_num)
#       4 display(results)
#       5 metric_plots(results, ylabel='PPV',
#       6              xlim1=[0.9*min(results.test_coverage),1.1*max(results.test_coverage)],
#       7              xlim2=[0.9*min(results.theta_star),1.1*max(results.theta_star)],
#       8              ylim=[0,1.1*max(results.train_metric)])
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\sgr_utils.py:229, in SGR_at_targets(train_set, test_set, k, delta, metric_targets, metric, union, mode, steps)
#     227     sgr_dico = SGR_dicho(delta, r_star, train_set, k, metric = metric, union = union)
#     228 elif mode == 'greedy':
# --> 229     sgr_dico = SGR_greedy_search(delta, r_star, train_set, metric, steps=steps)
#     230 else:
#     231     raise ValueError('mode should be either "greedy" or "dicho"')
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\sgr_utils.py:194, in SGR_greedy_search(delta, r_star, Sn, metric, steps, tolerance)
#     190 if selected_errs_count == 0:
#     191     # no mistake on selected subset => no mistake as next iters, so b* is stuck at 1-delta^(1/n)
#     192     return {}
# --> 194 b = B_star(delta,
#     195            selected_errs_count,
#     196            selected_samples.shape[0])
#     197 if b==1:
#     198     return {}
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
#     [... skipping similar frames: B_star at line 77 (2 times)]
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
#     [... skipping similar frames: B_star at line 79 (3 times), B_star at line 77 (1 times)]
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:79, in B_star(delta, e, n, eps, b1, b2)
#      77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
# ---> 79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:77, in B_star(delta, e, n, eps, b1, b2)
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
# ---> 77     return B_star(delta, e, n, b1=b1, b2=b)
#      78 else:
#      79     return B_star(delta, e, n, b1=b, b2=b2)
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:74, in B_star(delta, e, n, eps, b1, b2)
#      71     return 1-delta**(1/n)
#      73 b = (b1+b2)/2 # middle of segment
# ---> 74 if abs(binom_sum(b,e,n) - delta) < eps:
#      75     return b
#      76 elif binom_sum(b,e,n) <= delta - eps:
#
# File c:\Users\ejeme\Documents\python_repos\selective-classification\python_scripts\math_utils.py:53, in binom_sum(b, e, n)
#      43 """
#      44 binomial sum of term b in [0,1]
#      45 with binomial coefs "j among n"
#      46 for j in 0,1,...,e
#      47 it is the proba of doing at most e errors among n Bernoulli iid experiences with error proba b
#      48 """
#      49 if e < n:
#      50     v = np.array([
#      51         np.exp(
#      52             binomial_log(n, j)
# ---> 53             +j*np.log(b)
#      54             +(n-j)*np.log(1-b)) for j in range(e+1)])
#      55     return np.sum(v)
#      56 elif e == n:
#
# KeyboardInterrupt:

# %% [markdown]
# ### <font color = 'orange'> 3.4. __SE__

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, 
                         metric = 'SE', mode='greedy', steps=greedy_search_steps_num)
display(results)
metric_plots(results, ylabel='SE', 
             xlim1=[0.9*min(results.test_coverage),1.1*max(results.test_coverage)], 
             xlim2=[0.9*min(results.theta_star),1.1*max(results.theta_star)], 
             ylim=[0.5*min(results.metric_bound),1.1*max(results.metric_bound)])
# Out:
#    metric_target  metric_bound  theta_star  train_metric  train_coverage  \
# 0           0.20      0.693461   -0.028328      0.754557          1.0000
# 1           0.28      0.693461   -0.028328      0.754557          1.0000
# 2           0.35      0.693461   -0.028328      0.754557          1.0000
# 3           0.42      0.693461   -0.028328      0.754557          1.0000
# 4           0.48      0.693461   -0.028328      0.754557          1.0000
# 5           0.54      0.693461   -0.028328      0.754557          1.0000
# 6           0.59      0.693461   -0.028328      0.754557          1.0000
# 7           0.64      0.693461   -0.028328      0.754557          1.0000
# 8           0.68      0.693461   -0.028328      0.754557          1.0000
# 9           0.72      0.719163   -0.003469      0.789119          0.7951
#
#    test_metric  test_coverage
# 0     0.761752         0.9999
# 1     0.761752         0.9999
# 2     0.761752         0.9999
# 3     0.761752         0.9999
# 4     0.761752         0.9999
# 5     0.761752         0.9999
# 6     0.761752         0.9999
# 7     0.761752         0.9999
# 8     0.761752         0.9999
# 9     0.788124         0.7948

# %% [markdown]
# ### <font color = 'orange'> 3.5. __SP__

# %%
results = SGR_at_targets(train_set, test_set, k=int(np.log2(train_set.shape[0])),
                         delta=delta, metric_targets=metric_targets, 
                         metric = 'SP', mode='greedy', steps=greedy_search_steps_num)
display(results)
metric_plots(results, ylabel='SP',
             xlim1=[0.9*min(results.test_coverage),1.1*max(results.test_coverage)], 
             xlim2=[0.9*min(results.theta_star),1.1*max(results.theta_star)], 
             ylim=[0.5*min(results.metric_bound),1.1*max(results.metric_bound)])
# Out:
#     metric_target  metric_bound  theta_star  train_metric  train_coverage  \
# 0            0.20      0.828090   -0.028328      0.836007        1.000000
# 1            0.28      0.828090   -0.028328      0.836007        1.000000
# 2            0.35      0.828090   -0.028328      0.836007        1.000000
# 3            0.42      0.828090   -0.028328      0.836007        1.000000
# 4            0.48      0.828090   -0.028328      0.836007        1.000000
# 5            0.54      0.828090   -0.028328      0.836007        1.000000
# 6            0.59      0.828090   -0.028328      0.836007        1.000000
# 7            0.64      0.828090   -0.028328      0.836007        1.000000
# 8            0.68      0.828090   -0.028328      0.836007        1.000000
# 9            0.72      0.828090   -0.028328      0.836007        1.000000
# 10           0.76      0.828090   -0.028328      0.836007        1.000000
# 11           0.79      0.828090   -0.028328      0.836007        1.000000
# 12           0.82      0.828090   -0.028328      0.836007        1.000000
# 13           0.84      0.840218   -0.007516      0.848036        0.951900
# 14           0.86      0.864891   -0.004047      0.872569        0.835800
# 15           0.89      0.895640   -0.002313      0.903188        0.668500
# 16           0.90      0.915491   -0.001734      0.922838        0.568067
# 17           0.92      0.939965   -0.001156      0.947117        0.423900
# 18           0.93      0.939965   -0.001156      0.947117        0.423900
# 19           0.94      0.939965   -0.001156      0.947117        0.423900
# 20           0.95      0.959918   -0.000578      0.968270        0.222733
# 21           0.96      0.959918   -0.000578      0.968270        0.222733
#
#     test_metric  test_coverage
# 0      0.830630         0.9999
# 1      0.830630         0.9999
# 2      0.830630         0.9999
# 3      0.830630         0.9999
# 4      0.830630         0.9999
# 5      0.830630         0.9999
# 6      0.830630         0.9999
# 7      0.830630         0.9999
# 8      0.830630         0.9999
# 9      0.830630         0.9999
# 10     0.830630         0.9999
# 11     0.830630         0.9999
# 12     0.830630         0.9999
# 13     0.840662         0.9527
# 14     0.863212         0.8378
# 15     0.895771         0.6661
# 16     0.915653         0.5679
# 17     0.944935         0.4232
# 18     0.944935         0.4232
# 19     0.944935         0.4232
# 20     0.966213         0.2200
# 21     0.966213         0.2200
